# %%
from kaggle_environments import make
from lux.game import Game
from lux.game_map import Cell, RESOURCE_TYPES, Position
from lux.constants import Constants
from lux.game_constants import GAME_CONSTANTS
from lux import annotate
import math
import sys
import random

game_state = None

AGENT_VERSION=3
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
### HELPER FUNCTIONS


def city_needs_fuel(citytile):
    city = player.cities[citytile.cityid]
    return city.get_light_upkeep()*10 < city.fuel
    

########
# TIME #
########
def time_before_nightfall(observation):
    """
    Returns the number of steps before nightfall, 0 if it is the night
    """
    step = observation['step']%40
    return max(0,30-step)

def time_before_sunrise(observation):
    """
    Returns the number of steps before sunrise, 0 if it is the day
    """
    step = observation['step']%40
    if time_before_nightfall(observation) == 0:
        return 40-step
    else:
        return 0
    

def time_before_end(observation):
    """
    Returns the number of steps before the end of the simulation
    """
    step = observation['step']%40
    return 360-step


############
# MOVEMENT #
############

def is_in_map(pos):
    """
    Returns True if Position pos belongs to the map
    """
    x = pos.x
    y = pos.y
    w, h = game_state.map.width, game_state.map.height
    return (x<w)&(y<w)&(x>=0)&(y>=0)

# Redefine Position.direction_to to avoid citytiles
def direction_to_avoid_citytiles(unit, game_state, target_pos):
    """
    Returns closest position to target_pos from this position, if it is not a citytile (except target_pos)
    """
    DIRECTIONS = Constants.DIRECTIONS

    check_dirs = [
        DIRECTIONS.NORTH,
        DIRECTIONS.EAST,
        DIRECTIONS.SOUTH,
        DIRECTIONS.WEST,
    ]
    closest_dir = DIRECTIONS.CENTER

    i=0
    while i<4 and (is_in_map(unit.pos.translate(check_dirs[i], 1))) and (unit.pos.translate(check_dirs[i], 1) != target_pos and game_state.map.get_cell_by_pos(unit.pos.translate(check_dirs[i], 1)).citytile!=None):
        i+=1

    if i<4:
        direction = check_dirs[i]
        #print("====DEBUG==== direction",direction)

        newpos = unit.pos.translate(direction, 1)
        #print("====DEBUG==== newpos",newpos)
        #if newpos == target_pos or game_state.map.get_cell_by_pos(newpos).citytile==None:
        closest_dist = unit.pos.translate(check_dirs[i], 1).distance_to(target_pos)
        #print("====DEBUG==== closest_dist",closest_dist)

        #closest_dir = DIRECTIONS.CENTER
        closest_dir = check_dirs[i]
        #print("====DEBUG==== closest_dir",closest_dir)
        for direction in check_dirs:
            newpos = unit.pos.translate(direction, 1)
            if is_in_map(newpos):
                #print("====DEBUG==== newpos",newpos)
                #print("====DEBUG==== game_state.map.get_cell_by_pos(newpos).citytile",game_state.map.get_cell_by_pos(newpos).citytile)
                if game_state.map.get_cell_by_pos(newpos) != None:
                    if newpos == target_pos or game_state.map.get_cell_by_pos(newpos).citytile==None:
                        #print("====DEBUG==== dans le if")
                        dist = target_pos.distance_to(newpos)
                        #print("====DEBUG==== dist",dist)
                        if dist < closest_dist:
                            closest_dir = direction
                            closest_dist = dist
                            #print("====DEBUG==== MAJ. closest_dir",closest_dir,"closest_dist",closest_dist)

            #print("====DEBUG==== closest_dir",closest_dir)


    return closest_dir





##################
# CELLS RESEARCH #
##################

def is_buildable(cell):
    """
    Return True is the cell is not a city and not a resource
    """
    return (not cell.has_resource()) and cell.citytile == None

def adjacent_tiles(pos):
    """
    Get adjacent tiles given a tile
    """
    x1,y1 = pos.x, pos.y
    w, h = game_state.map.width, game_state.map.height
    adjacent_tiles_pos = [(x1-1,y1),(x1+1,y1),(x1,y1+1),(x1,y1-1)]
    return [ game_state.map.get_cell(x,y) for (x,y) in adjacent_tiles_pos if (x<w)&(y<w)&(x>=0)&(y>=0) ]


def find_empty(game_state):
    """
    Returns the list of empty Cell
    """
    empty_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if not cell.has_resource() and cell.citytile == None:
                empty_tiles.append(cell)
    return empty_tiles


def find_closest_empty(pos, player, empty_tiles):
    """
    Returns the closest empty Cell that a worker can build on.
    
    """
    closest_dist = math.inf
    closest_empty_tile = None
    
    for empty_tile in empty_tiles:
        dist = empty_tile.pos.distance_to(pos)
        if dist < closest_dist:
            closest_dist = dist
            closest_empty_tile = empty_tile
            
    return closest_empty_tile



def find_closest_empty_tile(pos, player):
    """
    Returns the closest empty Cell
    """
    closest_empty_tile = None

    closest_dist = math.inf
    for k, city in player.cities.items():
        for city_tile in city.citytiles:
            dist = city_tile.pos.distance_to(pos)
            if dist < closest_dist:
                closest_dist = dist
                closest_city_tile = city_tile
    return closest_city_tile

def find_closest_city_tile(pos, player):
    """
    Returns the closest city Cell
    """
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        for k, city in player.cities.items():
            for city_tile in city.citytiles:
                dist = city_tile.pos.distance_to(pos)
                if dist < closest_dist:
                    closest_dist = dist
                    closest_city_tile = city_tile
    return closest_city_tile

def find_closest_city_tile_in_city(pos, player, cit):
    """
    Returns the closest city Cell among the given City
    """
    closest_city_tile = None
    if len(player.cities) > 0:
        closest_dist = math.inf
        for k, city in player.cities.items():
            if city == cit:
                for city_tile in city.citytiles:
                    dist = city_tile.pos.distance_to(pos)
                    if dist < closest_dist:
                        closest_dist = dist
                        closest_city_tile = city_tile
    return closest_city_tile

def find_closest_cell_in_list(pos, list_cells):
    """
    Returns the closest Cell and corresponding distance, among the given list of Cell
    """
    closest_cell = None
    closest_dist = math.inf
    if len(list_cells) > 0:
        for c in list_cells:
            dist = c.pos.distance_to(pos)
            if dist < closest_dist:
                closest_dist = dist
                closest_cell = c
    return closest_cell, closest_dist


def citytiles_sorted_by_fuel_capacity(pos, player):
    """
    Returns the list of the closest citytiles belonging to different cities, sorted by amount of fuel available in the corresponding cities
    The number of elements of the resulting list is equal to the number of cities
    """
    res=[]
    if len(player.cities) > 0:
        for k, city in player.cities.items():
            city_tile = find_closest_city_tile_in_city(pos, player, city)
            res.append({"tile": city_tile, "fuel":city.fuel})
            
    if res!=[]:
        res= sorted(res, key=lambda x: x["fuel"], reverse=False)
    return res

def floodfill(pos):
    """
    Applies the floodfill algorithm to return the list of Cell connected to the given Position and having the same Resource type
    """
    res = []
    player_cell = game_state.map.get_cell_by_pos(pos)
    explored = [player_cell]
    to_explore = [player_cell]
    resource_type = player_cell.resource
    
    while to_explore != []:
        current_cell = to_explore.pop()
        if current_cell not in res:
            res.append(current_cell)
            neighborhood = adjacent_tiles(current_cell.pos)
            for a in neighborhood:
                if a not in explored:
                    if a.has_resource():
                        if a.resource.type == resource_type.type:
                            to_explore.append(a)
            explored.append(current_cell)
    return res

def get_clusters_of_resources(city_cell):
    """
    Returns a dict {closest_cell : [closest_dist, total_ressource]}
        closest_cell    : the closest Cell belonging to a cluster of same resource
        closest_dist    : the distance to closest_cell
        total_ressource : the total amount of resource the cluster contains
        
    """
    res={}
    list_clusters = []
    for x in range(game_state.map.width):
        for y in range(game_state.map.height):
            current_cell = game_state.map.get_cell(x,y)
            if current_cell.has_resource():
                if current_cell not in (item for sublist in list_clusters for item in sublist):
                    list_clusters.append(floodfill(current_cell.pos))
                    
    for s in list_clusters:
        total_resource = 0
        for c in s:
            total_resource += c.resource.amount
        
        closest_cell, closest_dist = find_closest_cell_in_list(city_cell.pos, s)
        res[closest_cell] = [closest_dist,total_resource]
    
    if res!=[]:
        res = dict(sorted(res.items(), key=lambda item: item[1][0]))
    return res

def get_neighborhood_cluster(cluster_cell):
    """
    Returns the list of cells around a cluster (cluster's enveloppe)
    """
    res=[]
    dict_tmp = {}
    cluster = floodfill(cluster_cell.pos)
    if cluster != []:
        for c in cluster:
            neighbors = adjacent_tiles(c.pos)
            for n in neighbors:
                if is_buildable(n):
                    dict_tmp[n] = cluster_cell.pos.distance_to(n.pos)
    
    # Sort cells by distance
    dict_tmp = dict(sorted(dict_tmp.items(), key=lambda item: item[1]))
    res = list(dict_tmp.keys())
    return res
    
    
def get_list_citytiles_in_neighborhood_cluster(cluster_cell):
    res=[]
    dict_tmp = {}
    neighborhood_cluster = get_neighborhood_cluster(cluster_cell)
    for n in neighborhood_cluster:
        if n.citytile != None:
            dict_tmp[n] = cluster_cell.pos.distance_to(n.pos)
            
    # Sort cells by distance
    dict_tmp = dict(sorted(dict_tmp.items(), key=lambda item: item[1]))
    res = list(dict_tmp.keys())
    return res
    
def get_closest_citytile_in_neighborhood_cluster_needing_fuel(cluster_cell):
    res = None
    dict_tmp = {}
    list_citytiles_in_neighborhood_cluster = get_list_citytiles_in_neighborhood_cluster(cluster_cell)
    for c in list_citytiles_in_neighborhood_cluster:
        if city_needs_fuel(c):
            dict_tmp[c] = cluster_cell.pos.distance_to(c.pos)
        
    dict_tmp = dict(sorted(dict_tmp.items(), key=lambda item: item[1]))
    dict_tmp = list(dict_tmp.keys())
    if dict_tmp != []:
        res = dict_tmp[0]
    return res

#########
# UNITS #
#########

def get_list_of_carts(player):
    """
    Returns the list of cart units
    """
    res = []
    for u in player.units:
        if u.is_cart():
            res.append(u)
    return res


def get_list_of_workers(player):
    """
    Returns the list of cart units
    """
    res = []
    for u in player.units:
        if u.is_worker():
            res.append(u)
    return res


#############
# RESOURCES #
#############
def find_resources(game_state):
    """
    Returns the list of resource Cell
    """
    resource_tiles: list[Cell] = []
    width, height = game_state.map_width, game_state.map_height
    for y in range(height):
        for x in range(width):
            cell = game_state.map.get_cell(x, y)
            if cell.has_resource():
                resource_tiles.append(cell)
    return resource_tiles


def find_closest_resources(pos, player, resource_tiles):
    """
    Returns the closest resource Cell that a worker can mine.
    Priority order : uranium, coal, wood
    """
    closest_dist = math.inf
    closest_resource_tile = None
    for resource_tile in resource_tiles:
        dist = resource_tile.pos.distance_to(pos)
        if dist < closest_dist:
            if (resource_tile.resource.type=='uranium') & (player.researched_uranium()): 
                closest_dist = dist
                closest_resource_tile = resource_tile
            elif (resource_tile.resource.type=='coal') & (player.researched_coal()): 
                closest_dist = dist
                closest_resource_tile = resource_tile
            elif (resource_tile.resource.type=='wood'):
                closest_dist = dist
                closest_resource_tile = resource_tile
    return closest_resource_tile



###########
# WORKERS #
###########

def building_tiles(player, pos): # TODO: change to pos, player)
    """
    Return the chosen Cell where the worker is going to build a city
    """
    list_adjacent_cells_to_city = []
    cities = []
    for k, city in player.cities.items():
        cities.append(city.citytiles)
    
    for city in cities:
        for citytile in city:
            neighborhood = adjacent_tiles(citytile.pos) # list of Cell
            for n in neighborhood:
                if n not in list_adjacent_cells_to_city and (n.has_resource()==False) & (n.citytile==None) :
                    list_adjacent_cells_to_city.append(n)
    closest_cell, closest_dist = find_closest_cell_in_list(pos, list_adjacent_cells_to_city)       
    return closest_cell

def move_worker(unit, target_cell, positions_occupied_next_round, actions, info_map):
    #print('====DEBUG== In move_worker. unit.pos', unit.pos)
    next_direction = unit.pos.direction_to(target_cell.pos)
    position_wanted = unit.pos.translate(next_direction, 1)
    #print('====DEBUG== position_wanted',position_wanted)
    
    if is_in_map(position_wanted):
        #print('====DEBUG== is_in_map(position_wanted)',is_in_map(position_wanted))
        # If no unit want to go there, move. Stay here else.
        if position_wanted not in positions_occupied_next_round:
            positions_occupied_next_round.append(position_wanted)
            action = unit.move(next_direction)
            actions.append(action)
            info_map[position_wanted.y][position_wanted.x]+=1
            #print('====DEBUG== position_wanted not in positions_occupied_next_round')
        else:
            # If another unit will go to the position_wanted in next step, choose randomly another Position around him
            neighborhood = adjacent_tiles(unit.pos)
            random.shuffle(neighborhood)
            for a in neighborhood:
                if a.pos not in positions_occupied_next_round:
                    next_direction = unit.pos.direction_to(a.pos)
                    positions_occupied_next_round.append(a.pos)
                    action = unit.move(next_direction)
                    actions.append(action)
                    info_map[a.pos.y][a.pos.x]+=1
                    #print('====DEBUG== position reserved:', a.pos)
                    break

def move_worker_avoid_city_tiles(unit, target_cell, positions_occupied_next_round, actions, info_map):
    #print('====DEBUG== In move_worker_avoid_city_tiles. unit.pos', unit.pos)
    #next_direction = unit.pos.direction_to(target_cell.pos)
    next_direction = direction_to_avoid_citytiles(unit, game_state, target_cell.pos)
    position_wanted = unit.pos.translate(next_direction, 1)
    #print('====DEBUG== position_wanted',position_wanted)
    
    if is_in_map(position_wanted):
        #print('====DEBUG== is_in_map(position_wanted)',is_in_map(position_wanted))
        # If no unit want to go there, move. Stay here else.
        if position_wanted not in positions_occupied_next_round:
            positions_occupied_next_round.append(position_wanted)
            action = unit.move(next_direction)
            actions.append(action)
            info_map[position_wanted.y][position_wanted.x]+=1
            #print('====DEBUG== position_wanted not in positions_occupied_next_round')
        else:
            # If another unit will go to the position_wanted in next step, choose randomly another Position around him
            neighborhood = adjacent_tiles(unit.pos)
            random.shuffle(neighborhood)
            for a in neighborhood:
                if a.pos not in positions_occupied_next_round:
                    next_direction = direction_to_avoid_citytiles(unit, game_state, a.pos)
                    positions_occupied_next_round.append(a.pos)
                    action = unit.move(next_direction)
                    actions.append(action)
                    info_map[a.pos.y][a.pos.x]+=1
                    #print('====DEBUG== position reserved:', a.pos)
                    break

#########
# CARTS #
#########
def move_cart(unit, positions_occupied_next_round, actions, info_map):
    """
    Strategy: build roads where units have been the most
    """
    neighborhood = adjacent_tiles(unit.pos)
    neighbor = neighborhood[0]
    min_info_map_value = info_map[neighbor.pos.y][neighbor.pos.x]
    
    for n in neighborhood[1:]:
        if n.citytile == None and n.has_resource()== False and info_map[n.pos.y][n.pos.x]<min_info_map_value:
            neighbor = n
            min_info_map_value = info_map[n.pos.y][n.pos.x]
    
    move_worker(unit, neighbor, positions_occupied_next_round, actions, info_map)
    
    
    '''
    # Strategy: select randomly the adjacent tile which has the less road value
    # -> Not efficient
    
    #print("==== DEBUG ==== Move cart. Pos", unit.pos)
    neighborhood = adjacent_tiles(unit.pos)
    random.shuffle(neighborhood)
    
    neighbor = neighborhood[0]
    min_road_value = neighbor.road
    
    for n in neighborhood[1:]:
        if n.citytile == None and n.has_resource()== False and n.road<min_road_value:
            neighbor = n
            min_road_value = n.road
    
    next_direction = unit.pos.direction_to(neighbor.pos)
    position_wanted = neighbor.pos.translate(next_direction, 1)
    
    if is_in_map(position_wanted):

        #print("==== DEBUG ==== next_direction", next_direction)
        #print("==== DEBUG ==== position_wanted", position_wanted)

        # If no unit want to go there, move. Stay here else.
        if position_wanted not in positions_occupied_next_round:
            positions_occupied_next_round.append(position_wanted)
            action = unit.move(next_direction)
            actions.append(action)
        else:
            neighborhood = adjacent_tiles(unit.pos)
            random.shuffle(neighborhood)
            for a in neighborhood:
                if a.pos not in positions_occupied_next_round:
                    positions_occupied_next_round.append(a.pos)
                    action = unit.move(next_direction)
                    actions.append(action)
                    break
    '''
    
##########
# CITIES #
##########
def cities_can_survive(unit, player, observation):
    res = True
    city_tiles_fuel = citytiles_sorted_by_fuel_capacity(unit.pos, player)
    for ct in city_tiles_fuel:
        required_fuel_city = player.cities[ct['tile'].cityid].get_light_upkeep()*time_before_sunrise(observation)
        res &= ct['fuel'] < required_fuel_city
    return res

# %%
def agent(observation, configuration):
    global game_state

    ### Do not edit ###
    if observation["step"] == 0:
        game_state = Game()
        game_state._initialize(observation["updates"])
        game_state._update(observation["updates"][2:])
        game_state.id = observation.player
    else:
        game_state._update(observation["updates"])
    
    actions = []

    ### AI Code goes down here! ### 
    
    

    player = game_state.players[observation.player]
    opponent = game_state.players[(observation.player + 1) % 2]
    width, height = game_state.map.width, game_state.map.height
    
    # add debug statements like so!
    if game_state.turn == 0:
        print("Agent is running!", file=sys.stderr)
        
    # DEBUG
    #print("###",time_before_nightfall(observation))
        
    
    
    # Shared data
    
    global positions_occupied_next_round
    global initial_city_cell
    global clusters_of_resources
    global info_carts
    global info_map
    
    
    
    # Clear the list positions_occupied_next_round
    positions_occupied_next_round = []
    
    
    # Get the cell of the initial city
    cities = list(player.cities.values())
    if game_state.turn == 0:
        initial_city_cell = game_state.map.get_cell_by_pos(cities[0].citytiles[0].pos)
    
    # Update the list of sets of resources
    clusters_of_resources = get_clusters_of_resources(initial_city_cell)
    
    # Update list of carts
    list_of_carts = get_list_of_carts(player)
    #if game_state.turn == 0:
    info_carts={}
    for i in list_of_carts:
        info_carts[i] = True # True : the cart must go to its target, False : it must return to the city
    
    # info_map is a copy of the map. Each element contains an integer counting the number of times a worker has been on.
    # Useful to pave a road
    if game_state.turn == 0:
        # Initialisation of info_map
        info_map = [None] * height
        for y in range(height):
            info_map[y] = [None] * width
            for x in range(width):
                info_map[y][x] = 0
        
        
        
        

    
    resource_tiles = find_resources(game_state)
    
    
    ##########
    # CITIES #
    ##########
    # Cities roles proportions
    p_worker = 1
    p_research = 0
    p_cart = 0
    
    # Compute roles of cities
    number_cities = player.city_tile_count
    index_tmp=0
    cities_indices = [*range(number_cities)]
    cities_worker = cities_indices[index_tmp:index_tmp+int(p_worker*number_cities)]
    index_tmp += int(p_worker*number_cities)
    cities_research = cities_indices[index_tmp:index_tmp+int(p_research*number_cities)]
    index_tmp += int(p_research*number_cities)
    cities_cart = cities_indices[index_tmp:]
    
    
    
    tiles_in_cities = [ ct for k,city in player.cities.items() for ct in city.citytiles ]
    for k, city in player.cities.items():
        for i,city_tile in enumerate(city.citytiles):
            if city_tile.can_act():
                closest_resource = find_closest_resources(city_tile.pos, player, resource_tiles)
                if closest_resource!= None:
                    closest_resource_dist = city_tile.pos.distance_to(closest_resource.pos)

                    if i in cities_worker:
                        if time_before_nightfall(observation) > closest_resource_dist and len(player.units) < player.city_tile_count:
                            action = city_tile.build_worker()
                            #print("<<< Build Worker >>>", action)
                            actions.append(action)
                        else :
                            action = city_tile.research()
                            #print('<<< Research >>> ')
                            actions.append(action)
                    elif i in cities_research:
                        if player.research_points < 200:
                            action = city_tile.research()
                            #print('<<< Research >>> ')
                            actions.append(action)
                        else :
                            if (i%2==0):
                                action = city_tile.build_cart()
                                #print("<<< Build Cart >>>", action)
                                actions.append(action)
                            else:
                                action = city_tile.build_worker()
                                #print("<<< Build Worker >>>", action)
                                actions.append(action)

                    else:
                        #if 
                        if time_before_nightfall(observation) > closest_resource_dist and len(player.units) < player.city_tile_count:
                            action = city_tile.build_cart()
                            #print("<<< Build Cart >>>", action)
                            actions.append(action)
                        else :
                            action = city_tile.research()
                            #print('<<< Research >>> ')
                            actions.append(action)

                        
                
                
                '''
                N=10
                if (i%N<5):
                    if len(player.units) < player.city_tile_count:
                        action = city_tile.build_worker()
                        #print("<<< Build Worker >>>", action)
                        actions.append(action)
                elif (5<=i%N<8):
                    action = city_tile.research()
                    #print('<<< Research >>> ')
                    actions.append(action)
                
                else:
                    if len(player.units) < player.city_tile_count:
                        action = city_tile.build_cart()
                        #print("<<< Build Cart >>>", action)
                        actions.append(action)
                '''
                
                
    #########
    # UNITS #
    #########
    
    for i, unit in enumerate(player.units):
        
        ###########
        # WORKERS #
        ###########
        if unit.is_worker() and unit.can_act():
            if player.city_tile_count==0:
                #print('==DEBUG== EMERGENCY. Worker build a city')
                empty_tiles = find_empty(game_state)
                closest_empty_cell = find_closest_empty(unit.pos, player, empty_tiles)
                
                if unit.pos.equals(closest_empty_cell.pos):
                    #print('==DEBUG== Worker on tile_to_build')
                    if unit.can_build(game_state.map):
                        #print('==DEBUG== Worker can build')
                        action = unit.build_city()
                        actions.append(action)
                else:
                    #print('==DEBUG== Worker move')
                    move_worker(unit, closest_empty_cell, positions_occupied_next_round, actions, info_map)
                #action = unit.build_city()
                #actions.append(action)
                
            else:
                
                closest_city_tile = find_closest_city_tile(unit.pos, player)
                closest_resource_tile = find_closest_resources(unit.pos,player,resource_tiles)
                #cluster = get_clusters_of_resources(closest_resource_tile)
                if closest_resource_tile != None:
                    neighborhood_cluster = get_neighborhood_cluster(closest_resource_tile)



                    # If there is still space in the cargo, move to the closest resource tile (if possible)
                    if unit.get_cargo_space_left()>0:
                        move_worker(unit, closest_resource_tile, positions_occupied_next_round, actions, info_map)

                    # If the cargo is full.
                    else:

                        # If there is no city in the cluster's neighborhood, build one
                        list_citytiles_in_neighborhood_cluster = get_list_citytiles_in_neighborhood_cluster(closest_resource_tile)

                        if list_citytiles_in_neighborhood_cluster==[]:

                            # Build around the cluster
                            if neighborhood_cluster != []:
                                closest_buildable_tile = neighborhood_cluster[0]

                                if unit.pos.equals(closest_buildable_tile.pos):
                                        #print('==DEBUG== Worker on tile_to_build')
                                        if unit.can_build(game_state.map):
                                            #print('==DEBUG== Worker can build')
                                            action = unit.build_city()
                                            actions.append(action)
                                else:
                                    move_worker(unit, closest_buildable_tile, positions_occupied_next_round, actions, info_map)
                            else:
                                if unit.pos.equals(closest_city_tile.pos):
                                        #print('==DEBUG== Worker on tile_to_build')
                                        if unit.can_build(game_state.map):
                                            #print('==DEBUG== Worker can build')
                                            action = unit.build_city()
                                            actions.append(action)
                                else:
                                    move_worker(unit, closest_city_tile, positions_occupied_next_round, actions, info_map)


                        else:
                            # If there are cities around the cluster, give the resource to the cities if needed, build new one else
                            closest_citytile_in_neighborhood_cluster_needing_fuel = get_closest_citytile_in_neighborhood_cluster_needing_fuel(closest_resource_tile)

                            # If no city needs fuel, build around the cluster
                            if closest_citytile_in_neighborhood_cluster_needing_fuel == []:
                                # Build around the cluster
                                if neighborhood_cluster != []:
                                    closest_buildable_tile = neighborhood_cluster[0]

                                    if unit.pos.equals(closest_buildable_tile.pos):
                                            #print('==DEBUG== Worker on tile_to_build')
                                            if unit.can_build(game_state.map):
                                                #print('==DEBUG== Worker can build')
                                                action = unit.build_city()
                                                actions.append(action)
                                    else:
                                        move_worker(unit, closest_buildable_tile, positions_occupied_next_round, actions, info_map)
                                else:
                                    if unit.pos.equals(closest_city_tile.pos):
                                            #print('==DEBUG== Worker on tile_to_build')
                                            if unit.can_build(game_state.map):
                                                #print('==DEBUG== Worker can build')
                                                action = unit.build_city()
                                                actions.append(action)
                                    else:
                                        move_worker(unit, closest_city_tile, positions_occupied_next_round, actions, info_map)

                            # If a city needs fuel, bring resource to it
                            else:
                                closest_city_needing_fuel = closest_citytile_in_neighborhood_cluster_needing_fuel[0]
                                move_worker(unit, closest_city_needing_fuel, positions_occupied_next_round, actions, info_map)

                        '''
                        city_tiles_fuel = citytiles_sorted_by_fuel_capacity(unit.pos, player)

                        # We are winning if we have more than 3 times more citytiles than the opponent
                        we_are_winning = opponent.city_tile_count*3<player.city_tile_count

                        go_to_city_tile = False    
                        for ct in city_tiles_fuel:
                            required_fuel_city = player.cities[ct['tile'].cityid].get_light_upkeep()*10

                            if ct['fuel'] < required_fuel_city or we_are_winning:
                                #print("==== DEBUG ==== GOTOCITY")
                                move_worker(unit, ct['tile'], positions_occupied_next_round, actions, info_map)
                                go_to_city_tile = True



                        # BUILD
                        if not go_to_city_tile:
                            #print("==== DEBUG ==== GO BUILD")
                            tile_to_build = building_tiles(player, unit.pos)
                            #print("==== DEBUG ==== tile_to_build",tile_to_build.pos)
                            #print('==DEBUG== Worker pos',unit.pos)
                            if tile_to_build != None:
                                #print('==DEBUG== tile_to_build.pos',tile_to_build.pos)

                                if unit.pos.equals(tile_to_build.pos):
                                    #print('==DEBUG== Worker on tile_to_build')
                                    if unit.can_build(game_state.map):
                                        #print('==DEBUG== Worker can build')
                                        action = unit.build_city()
                                        actions.append(action)
                                else:
                                    #print('==DEBUG== Worker move')
                                    move_worker_avoid_city_tiles(unit, tile_to_build, positions_occupied_next_round, actions, info_map)
                        '''
        
        #########
        # CARTS #
        #########
        if unit.is_cart() and unit.can_act():
            move_cart(unit, positions_occupied_next_round, actions, info_map)
    #print(actions)
    return actions

# %%
env = make("lux_ai_2021", configuration={"seed": 1, "loglevel": 2, "annotations": True}, debug=True)
#env = make("lux_ai_2021" , debug=True)
steps = env.run([agent, agent])
env.render(mode="ipython", width=800, height=600)
# Out:
# Agent is running!
# Agent is running!
# [WARN] (match_6V31iMy4XiZM) - turn 6; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 6; Unit u_4 collided when trying to move s to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 8; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 10; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 11; Unit u_4 collided when trying to move e to (13, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 12; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 13; Unit u_5 collided when trying to move w to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 14; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (11, 12) but unit cap reached. Build more CityTiles!; turn 15; cmd: bw 11 12
# [WARN] (match_6V31iMy4XiZM) - turn 16; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 16; Unit u_6 collided when trying to move n to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 18; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 19; Unit u_4 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 20; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 22; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 23; Unit u_4 collided when trying to move w to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 24; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 26; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 27; Unit u_4 collided when trying to move w to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 28; Unit u_1 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 30; Unit u_3 collided when trying to move s to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 30; Unit u_2 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 31; Unit u_7 collided when trying to move w to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 31; Unit u_2 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 32; Unit u_7 collided when trying to move w to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 32; Unit u_2 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 33; Unit u_7 collided when trying to move w to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 33; Unit u_2 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 35; Unit u_7 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 36; Unit u_7 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 37; Unit u_7 collided when trying to move s to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 43; Unit u_3 collided when trying to move s to (5, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 44; Unit u_7 collided when trying to move e to (12, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (10, 12) but unit cap reached. Build more CityTiles!; turn 45; cmd: bw 10 12
# [WARN] (match_6V31iMy4XiZM) - turn 45; Unit u_3 collided when trying to move w to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 46; Unit u_8 collided when trying to move w to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (11, 14) but unit cap reached. Build more CityTiles!; turn 48; cmd: bw 11 14
# [WARN] (match_6V31iMy4XiZM) - turn 48; Unit u_3 collided when trying to move w to (4, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 49; Unit u_3 collided when trying to move w to (4, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 49; Unit u_2 collided when trying to move e to (11, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 51; Unit u_11 collided when trying to move n to (4, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 51; Unit u_9 collided when trying to move w to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 53; Unit u_10 collided when trying to move w to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 54; Unit u_11 collided when trying to move n to (3, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 54; Unit u_5 collided when trying to move w to (8, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 54; Unit u_9 collided when trying to move w to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 54; Unit u_10 collided when trying to move w to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 54; Unit u_8 collided when trying to move w to (8, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (4, 15) but unit cap reached. Build more CityTiles!; turn 55; cmd: bw 4 15
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 14) but unit cap reached. Build more CityTiles!; turn 55; cmd: bw 8 14
# [WARN] (match_6V31iMy4XiZM) - turn 56; Unit u_9 collided when trying to move s to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 56; Unit u_14 collided when trying to move e to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 57; Unit u_11 collided when trying to move w to (2, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 57; Unit u_2 collided when trying to move n to (9, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 57; Unit u_14 collided when trying to move e to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 57; Unit u_7 collided when trying to move s to (9, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (9, 15) but unit cap reached. Build more CityTiles!; turn 58; cmd: bw 9 15
# [WARN] (match_6V31iMy4XiZM) - turn 58; Unit u_2 collided when trying to move e to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 58; Unit u_5 collided when trying to move s to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 59; Unit u_17 collided when trying to move e to (3, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 59; Unit u_14 collided when trying to move e to (9, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 60; Unit u_9 collided when trying to move w to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 61; Unit u_12 collided when trying to move e to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 61; Unit u_5 collided when trying to move e to (10, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 61; Unit u_10 collided when trying to move s to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 61; Unit u_7 collided when trying to move w to (10, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 63; Unit u_5 collided when trying to move w to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 63; Unit u_8 collided when trying to move w to (10, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 64; Unit u_12 collided when trying to move e to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (7, 14) but unit cap reached. Build more CityTiles!; turn 65; cmd: bw 7 14
# [WARN] (match_6V31iMy4XiZM) - turn 65; Unit u_7 collided when trying to move w to (10, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (3, 14) but unit cap reached. Build more CityTiles!; turn 66; cmd: bw 3 14
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (7, 14) but unit cap reached. Build more CityTiles!; turn 66; cmd: bw 7 14
# [WARN] (match_6V31iMy4XiZM) - turn 66; Unit u_5 collided when trying to move w to (10, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 66; Unit u_9 collided when trying to move w to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 66; Unit u_14 collided when trying to move e to (9, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 67; Unit u_3 collided when trying to move s to (6, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 67; Unit u_17 collided when trying to move w to (3, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 67; Unit u_15 collided when trying to move e to (12, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (6, 15) but unit cap reached. Build more CityTiles!; turn 68; cmd: bw 6 15
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 68; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 68; Unit u_5 collided when trying to move w to (9, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 68; Unit u_10 collided when trying to move s to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 69; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 69; Unit u_11 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 69; Unit u_24 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 69; Unit u_10 collided when trying to move s to (9, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 69; Unit u_13 collided when trying to move w to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 70; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 70; Unit u_3 collided when trying to move n to (6, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 70; Unit u_12 collided when trying to move n to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 70; Unit u_11 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 70; Unit u_21 collided when trying to move n to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_2 onto opponent CityTile; turn 71; cmd: m u_2 w
# [WARN] (match_6V31iMy4XiZM) - turn 71; Unit u_15 collided when trying to move w to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_2 onto opponent CityTile; turn 72; cmd: m u_2 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 72; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 72; Unit u_17 collided when trying to move e to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 72; Unit u_5 collided when trying to move s to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_2 onto opponent CityTile; turn 73; cmd: m u_2 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 73; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 73; Unit u_3 collided when trying to move s to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 73; Unit u_1 collided when trying to move e to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 73; Unit u_17 collided when trying to move e to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 73; Unit u_5 collided when trying to move s to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 74; Unit u_17 collided when trying to move e to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 75; Unit u_21 collided when trying to move e to (5, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 75; Unit u_7 collided when trying to move w to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 75; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 76; Unit u_21 collided when trying to move e to (5, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 76; Unit u_7 collided when trying to move w to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 76; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 77; Unit u_17 collided when trying to move e to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 77; Unit u_21 collided when trying to move e to (5, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 77; Unit u_7 collided when trying to move w to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 77; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 78; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 79; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_1 collided when trying to move c to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_2 collided when trying to move w to (6, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_11 collided when trying to move c to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_10 collided when trying to move w to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 80; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 81; Unit u_11 collided when trying to move e to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 81; Unit u_12 collided when trying to move e to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 81; Unit u_21 collided when trying to move s to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 81; Unit u_2 collided when trying to move s to (7, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 81; Unit u_1 collided when trying to move e to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 82; Unit u_1 collided when trying to move s to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 82; Unit u_14 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 82; Unit u_11 collided when trying to move s to (6, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 83; Unit u_1 collided when trying to move s to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 83; Unit u_2 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 83; Unit u_11 collided when trying to move s to (6, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 83; Unit u_12 collided when trying to move s to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (6, 15) but unit cap reached. Build more CityTiles!; turn 84; cmd: bw 6 15
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 84; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - turn 84; Unit u_1 collided when trying to move s to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 84; Unit u_2 collided when trying to move w to (6, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 84; Unit u_10 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (6, 15) but unit cap reached. Build more CityTiles!; turn 85; cmd: bw 6 15
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (6, 14) but unit cap reached. Build more CityTiles!; turn 85; cmd: bw 6 14
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 85; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_10 onto opponent CityTile; turn 85; cmd: m u_10 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 85; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 85; Unit u_21 collided when trying to move s to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 85; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 85; Unit u_30 collided when trying to move w to (8, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 86; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_10 onto opponent CityTile; turn 86; cmd: m u_10 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 86; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 86; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 86; Unit u_30 collided when trying to move e to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 87; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 87; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_28 onto opponent CityTile; turn 87; cmd: m u_28 w
# [WARN] (match_6V31iMy4XiZM) - turn 87; Unit u_1 collided when trying to move w to (5, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 87; Unit u_12 collided when trying to move s to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 87; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 87; Unit u_5 collided when trying to move w to (8, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 87; Unit u_10 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 88; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_10 onto opponent CityTile; turn 88; cmd: m u_10 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 88; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 88; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 88; Unit u_25 collided when trying to move n to (9, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 88; Unit u_28 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 88; Unit u_30 collided when trying to move e to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 89; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 89; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_28 onto opponent CityTile; turn 89; cmd: m u_28 w
# [WARN] (match_6V31iMy4XiZM) - turn 89; Unit u_20 collided when trying to move e to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 89; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 89; Unit u_7 collided when trying to move s to (8, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 89; Unit u_36 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 90; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 90; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_28 onto opponent CityTile; turn 90; cmd: m u_28 w
# [WARN] (match_6V31iMy4XiZM) - turn 90; Unit u_31 collided when trying to move s to (5, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 90; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 90; Unit u_26 collided when trying to move e to (10, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 90; Unit u_36 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 91; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 91; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_36 onto opponent CityTile; turn 91; cmd: m u_36 w
# [WARN] (match_6V31iMy4XiZM) - turn 91; Unit u_11 collided when trying to move s to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 91; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 91; Unit u_5 collided when trying to move s to (8, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 91; Unit u_10 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 92; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 92; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 92; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 92; Unit u_10 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 92; Unit u_25 collided when trying to move n to (9, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 92; Unit u_27 collided when trying to move n to (10, 11)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_3 onto opponent CityTile; turn 93; cmd: m u_3 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_10 onto opponent CityTile; turn 93; cmd: m u_10 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 93; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 93; Unit u_1 collided when trying to move n to (5, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 93; Unit u_20 collided when trying to move e to (5, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 93; Unit u_2 collided when trying to move s to (7, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 93; Unit u_7 collided when trying to move w to (8, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 93; Unit u_30 collided when trying to move n to (9, 11)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_10 onto opponent CityTile; turn 94; cmd: m u_10 w
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to move unit u_14 onto opponent CityTile; turn 95; cmd: m u_14 w
# [WARN] (match_6V31iMy4XiZM) - turn 95; Unit u_11 collided when trying to move n to (5, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 95; Unit u_10 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 96; Unit u_5 collided when trying to move n to (8, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 97; Unit u_1 collided when trying to move n to (5, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 97; Unit u_36 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 98; Unit u_26 collided when trying to move n to (8, 12)
# [WARN] (match_6V31iMy4XiZM) - turn 98; Unit u_33 collided when trying to move e to (10, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 98; Unit u_30 collided when trying to move n to (9, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 99; Unit u_14 collided when trying to move n to (7, 13)
# [WARN] (match_6V31iMy4XiZM) - turn 100; Unit u_25 collided when trying to move n to (10, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 102; Unit u_7 collided when trying to move n to (9, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 108; Unit u_37 collided when trying to move w to (12, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 110; Unit u_32 collided when trying to move e to (14, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 115; Unit u_28 collided when trying to move e to (12, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 115; Unit u_5 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 116; Unit u_28 collided when trying to move n to (11, 7)
# [WARN] (match_6V31iMy4XiZM) - turn 116; Unit u_5 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 117; Unit u_28 collided when trying to move n to (11, 7)
# [WARN] (match_6V31iMy4XiZM) - turn 117; Unit u_5 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 118; Unit u_28 collided when trying to move n to (11, 7)
# [WARN] (match_6V31iMy4XiZM) - turn 118; Unit u_5 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 121; Unit u_2 collided when trying to move e to (5, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 121; Unit u_25 collided when trying to move e to (13, 8)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (7, 14) but unit cap reached. Build more CityTiles!; turn 122; cmd: bw 7 14
# [WARN] (match_6V31iMy4XiZM) - turn 122; Unit u_3 collided when trying to move w to (5, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 122; Unit u_25 collided when trying to move e to (13, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 123; Unit u_3 collided when trying to move w to (5, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 123; Unit u_25 collided when trying to move e to (13, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 123; Unit u_33 collided when trying to move s to (12, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 124; Unit u_7 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 13) but unit cap reached. Build more CityTiles!; turn 125; cmd: bw 8 13
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (5, 9) but unit cap reached. Build more CityTiles!; turn 125; cmd: bw 5 9
# [WARN] (match_6V31iMy4XiZM) - turn 125; Unit u_3 collided when trying to move w to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 125; Unit u_26 collided when trying to move w to (10, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 125; Unit u_7 collided when trying to move n to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 125; Unit u_45 collided when trying to move w to (12, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 125; Unit u_47 collided when trying to move w to (4, 8)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (10, 12) but unit cap reached. Build more CityTiles!; turn 126; cmd: bw 10 12
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 13) but unit cap reached. Build more CityTiles!; turn 126; cmd: bw 8 13
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 14) but unit cap reached. Build more CityTiles!; turn 126; cmd: bw 8 14
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (5, 9) but unit cap reached. Build more CityTiles!; turn 126; cmd: bw 5 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (10, 8) but unit cap reached. Build more CityTiles!; turn 126; cmd: bw 10 8
# [WARN] (match_6V31iMy4XiZM) - turn 126; Unit u_26 collided when trying to move s to (11, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 126; Unit u_5 collided when trying to move e to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 13) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 8 13
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 14) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 8 14
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (13, 9) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 13 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (5, 9) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 5 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (10, 8) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 10 8
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (11, 9) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 11 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (12, 7) but unit cap reached. Build more CityTiles!; turn 127; cmd: bw 12 7
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_33 collided when trying to move n to (13, 7)
# [WARN] (match_6V31iMy4XiZM) - turn 127; Unit u_50 collided when trying to move n to (11, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_3 collided when trying to move s to (4, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_30 collided when trying to move s to (12, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_35 collided when trying to move e to (11, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_40 collided when trying to move n to (9, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 128; Unit u_41 collided when trying to move n to (12, 9)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 129; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 129; Unit u_47 collided when trying to move s to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 130; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (9, 13) but unit cap reached. Build more CityTiles!; turn 130; cmd: bw 9 13
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (12, 10) but unit cap reached. Build more CityTiles!; turn 130; cmd: bw 12 10
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (2, 9) but unit cap reached. Build more CityTiles!; turn 130; cmd: bw 2 9
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_47 collided when trying to move s to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_53 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_34 collided when trying to move w to (9, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 130; Unit u_45 collided when trying to move s to (13, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 131; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_3 collided when trying to move e to (5, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_12 collided when trying to move n to (4, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_53 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_2 collided when trying to move c to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 131; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 132; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_35 collided when trying to move n to (10, 7)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_51 collided when trying to move n to (10, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 132; Unit u_52 collided when trying to move n to (10, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 133; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_55 collided when trying to move w to (4, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 133; Unit u_7 collided when trying to move n to (13, 7)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 134; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (5, 8) but unit cap reached. Build more CityTiles!; turn 134; cmd: bw 5 8
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (4, 7) but unit cap reached. Build more CityTiles!; turn 134; cmd: bw 4 7
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_12 collided when trying to move n to (4, 1)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_53 collided when trying to move n to (4, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 134; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (4, 1) but unit cap reached. Build more CityTiles!; turn 135; cmd: bw 4 1
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 135; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 135; Unit u_56 collided when trying to move n to (13, 7)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 136; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_2 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 136; Unit u_53 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 137; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 137; Unit u_38 collided when trying to move n to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 137; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 137; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 137; Unit u_36 collided when trying to move e to (4, 9)
# [WARN] (match_6V31iMy4XiZM) - turn 137; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 138; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 138; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (9, 12) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 9 12
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 13) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 8 13
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (8, 14) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 8 14
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (13, 9) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 13 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (5, 9) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 5 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (4, 9) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 4 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (10, 8) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 10 8
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (11, 9) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 11 9
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (12, 7) but unit cap reached. Build more CityTiles!; turn 138; cmd: bw 12 7
# [WARN] (match_6V31iMy4XiZM) - turn 138; Unit u_12 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 138; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 138; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 138; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 139; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 139; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 139; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 139; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 139; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 139; Unit u_28 collided when trying to move n to (10, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 139; Unit u_35 collided when trying to move n to (10, 4)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to build unit on tile (3, 0) but unit cap reached. Build more CityTiles!; turn 140; cmd: bw 3 0
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 140; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 140; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_46 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_28 collided when trying to move e to (11, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_35 collided when trying to move n to (10, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_39 collided when trying to move w to (11, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_49 collided when trying to move n to (12, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 140; Unit u_43 collided when trying to move e to (6, 8)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 141; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 141; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 141; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (2, 8) but unit cap reached. Build more CityTiles!; turn 141; cmd: bw 2 8
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (3, 10) but unit cap reached. Build more CityTiles!; turn 141; cmd: bw 3 10
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_25 collided when trying to move n to (11, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_28 collided when trying to move e to (11, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_35 collided when trying to move n to (10, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_50 collided when trying to move w to (10, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_39 collided when trying to move n to (12, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 141; Unit u_49 collided when trying to move n to (12, 5)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 142; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 142; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 142; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_12 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_5 collided when trying to move s to (12, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_26 collided when trying to move s to (11, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_45 collided when trying to move e to (14, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_7 collided when trying to move n to (13, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_56 collided when trying to move n to (13, 4)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_39 collided when trying to move e to (13, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_49 collided when trying to move n to (12, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_50 collided when trying to move s to (11, 6)
# [WARN] (match_6V31iMy4XiZM) - turn 142; Unit u_62 collided when trying to move e to (3, 9)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 143; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 143; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 143; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - turn 143; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 143; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 143; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 144; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 144; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 144; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_43 collided when trying to move s to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_46 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_39 collided when trying to move n to (12, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_50 collided when trying to move n to (11, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_63 collided when trying to move s to (11, 5)
# [WARN] (match_6V31iMy4XiZM) - turn 144; Unit u_64 collided when trying to move e to (13, 4)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 145; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 145; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 145; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (4, 7) but unit cap reached. Build more CityTiles!; turn 145; cmd: bw 4 7
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (3, 7) but unit cap reached. Build more CityTiles!; turn 145; cmd: bw 3 7
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_59 collided when trying to move n to (5, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_5 collided when trying to move e to (14, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_30 collided when trying to move e to (13, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_39 collided when trying to move n to (12, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_10 collided when trying to move s to (3, 8)
# [WARN] (match_6V31iMy4XiZM) - turn 145; Unit u_50 collided when trying to move w to (10, 4)
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_38 onto opponent CityTile; turn 146; cmd: m u_38 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_42 onto opponent CityTile; turn 146; cmd: m u_42 n
# [WARN] (match_6V31iMy4XiZM) - Agent 0 tried to move unit u_53 onto opponent CityTile; turn 146; cmd: m u_53 s
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (3, 7) but unit cap reached. Build more CityTiles!; turn 146; cmd: bw 3 7
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (14, 3) but unit cap reached. Build more CityTiles!; turn 146; cmd: bw 14 3
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_12 collided when trying to move n to (4, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_44 collided when trying to move n to (5, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_59 collided when trying to move n to (5, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_48 collided when trying to move n to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_57 collided when trying to move n to (4, 11)
# [WARN] (match_6V31iMy4XiZM) - turn 146; Unit u_5 collided when trying to move s to (13, 4)
# ...
# [WARN] (match_6V31iMy4XiZM) - turn 236; Unit u_34 collided when trying to move s to (3, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 236; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 237; Unit u_2 collided when trying to move s to (3, 3)
# [WARN] (match_6V31iMy4XiZM) - turn 237; Unit u_34 collided when trying to move s to (3, 2)
# [WARN] (match_6V31iMy4XiZM) - turn 237; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 238; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 239; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - Agent 1 tried to build unit on tile (12, 7) but unit cap reached. Build more CityTiles!; turn 240; cmd: bw 12 7
# [WARN] (match_6V31iMy4XiZM) - turn 240; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 241; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 242; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 243; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 244; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 245; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 246; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 247; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 248; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 249; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 250; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 251; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 252; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 253; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 254; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 255; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 256; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 257; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 257; Unit u_114 collided when trying to move w to (2, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 258; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 259; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 260; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 260; Unit u_115 collided when trying to move s to (15, 14)
# [WARN] (match_6V31iMy4XiZM) - turn 261; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 262; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 263; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 264; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 265; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 266; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 267; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 268; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 269; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 270; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 271; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 272; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 273; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 274; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 275; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 276; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 277; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 278; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 279; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 280; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 281; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 282; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 283; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 284; Unit u_94 collided when trying to move e to (15, 15)
# [WARN] (match_6V31iMy4XiZM) - turn 284; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 285; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 286; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 287; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 288; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 289; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 290; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 291; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 292; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 293; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 294; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 295; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 296; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 297; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 298; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 299; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 300; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 301; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 302; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 303; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 304; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 305; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 306; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 307; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 308; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 309; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 310; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 311; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 312; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 313; Unit u_97 collided when trying to move s to (4, 10)
# [WARN] (match_6V31iMy4XiZM) - turn 314; Unit u_97 collided when trying to move s to (4, 10)
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;fc7718da-25b7-11ec-90a2-374e3df5463b&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 1,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 16,
#             &quot;height&quot;: 16,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;16 16&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r uranium 0 15 333&quot;,
#               &quot;r wood 2 1 377&quot;,
#               &quot;r wood 2 2 336&quot;,
#               &quot;r wood 2 3 341&quot;,
#               &quot;r wood 3 1 366&quot;,
#               &quot;r wood 3 2 359&quot;,
#               &quot;r wood 3 3 320&quot;,
#               &quot;r coal 3 8 394&quot;,
#               &quot;r coal 3 9 382&quot;,
#               &quot;r wood 3 13 800&quot;,
#               &quot;r wood 4 2 300&quot;,
#               &quot;r wood 4 3 302&quot;,
#               &quot;r coal 4 8 422&quot;,
#               &quot;r coal 4 9 361&quot;,
#               &quot;r wood 4 13 800&quot;,
#               &quot;r wood 5 13 357&quot;,
#               &quot;r wood 5 14 374&quot;,
#               &quot;r wood 5 15 800&quot;,
#               &quot;r wood 6 13 346&quot;,
#               &quot;r wood 6 14 301&quot;,
#               &quot;r wood 9 13 346&quot;,
#               &quot;r wood 9 14 301&quot;,
#               &quot;r wood 10 13 357&quot;,
#               &quot;r wood 10 14 374&quot;,
#               &quot;r wood 10 15 800&quot;,
#               &quot;r wood 11 2 300&quot;,
#               &quot;r wood 11 3 302&quot;,
#               &quot;r coal 11 8 422&quot;,
#               &quot;r coal 11 9 361&quot;,
#               &quot;r wo
